# %%
import numpy as np
import matplotlib.pyplot as plt
import tess_lc
import importlib
importlib.reload(tess_lc)
name_arr, ra_arr, dec_arr, spt_arr, T_arr, ldisk = tess_lc.catalog_load_and_save("./debris/table.dat")
table = np.load("catalog.npz")
tess_lc.main(name_arr, ra_arr, dec_arr, until_i =10000, size =70 , start_star = "16Com", replace=True, pca_comp = 3, ap_wd=5)
# Out:
# ---Analyze: 16Com -----
# 186.74712499999998 26.82563888888889
# Num of Sectors: 1
# 131.071826171875 103.98067169189453
# 104.76543
# Num of stars: 18
# /Users/masatakaaizawa/research/current_research/TESS_Lc/tess_lc.py:414: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(image))
# ---Analyze End: 16Com -----
#
# ---Analyze: HD108874 -----
# 187.61241666666666 22.879555555555555
# Num of Sectors: 1
# /Users/masatakaaizawa/research/current_research/TESS_Lc/tess_lc.py:46: RuntimeWarning: invalid value encountered in less
#   flag = light_all < median_50[i] + 3* (median_50[i] - median_16[i] )
# /Users/masatakaaizawa/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/masatakaaizawa/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# ...

# %%
test = np.zeros((2,3))
test2 =  np.zeros((2,5))
test3 = []
test4 = np.zeros(2, dtype=object)
test3.append(test)
test3.append(test2)
test4[0] = test
test4[1] = test3
print(len(test3))
print(np.array(test3, dtype=object))

# %%
data = np.load("./tess_output/output/HR9102/lcs.npz")

# %%
#plt.scatter(data["time"], data["target_pca"]/np.median(data["target_pca"]))
plt.plot(data["time"][0], data["target_pca"]/np.median(data["target_pca"]))


#plt.ylim(0.995, 1.005)
#print(np.shape(data["lcs_ori_all"]))

# %%
time = data["time"]
print(np.shape(tess_lc.time_to_times(time)))

# %%
print(np.shape(data["target_pca"]))
print(np.shape(data["time"]))
print(np.shape(data["lcs_ori_all"]))
plt.plot(time_arr[0], target_pca/np.median(target_pca))
plt.plot(time_arr[0], lcs_ori_all[0][10]/np.median(lcs_ori_all[0][10]))
plt.plot(time_arr[0], lcs_pca_all[0][10]/np.median(lcs_pca_all[0][10]))
plt.ylim(0.975,1.02)
print(icen_arr)
print(np.shape(lcs_pca_all))

# %%
lcs = lcs_ori_all[0]
for i in range(len(lcs)):
    plt.plot(time_arr[0], lcs[i]/np.median( lcs[i]), alpha = 0.6, lw = .11)
    plt.plot(time_arr[0],target_ori/np.median(target_ori), color="k", lw = 1)
    plt.plot(time_arr[0],target_pca/np.median(target_pca), color ="r", lw = 1)
    plt.ylim(0.975, 1.025)

# %%
plt.imshow(images[0], vmax = 100)

# %%
plt.imshow(pos_peaks[0])

# %%
test = np.asarray(["fgsfds" ,"fdsfdffd", "absfsd"])

# %%
print(test[0][2:4])
